# %%
import numpy as np
import pandas as pd

# %%
file = "assets/city_weather_data.csv"
data = pd.read_csv(file)
modify = data.rename(columns={"Unnamed: 0": "City_ID"})
indexed = modify.set_index("City_ID")
indexed
# Out:
#                    City  Cloudiness (%) Country                 Date  \
# City_ID
# 0               Ushuaia              40      AR  2020-03-04 05:28:50
# 1           Tuktoyaktuk              20      CA  2020-03-04 05:33:01
# 2                 Bluff              34      NZ  2020-03-04 05:33:01
# 3               Rikitea             100      PF  2020-03-04 05:33:01
# 4              Seminole               1      US  2020-03-04 05:33:02
# ...                 ...             ...     ...                  ...
# 596              Amahai              29      ID  2020-03-04 05:35:12
# 597            Vallenar               0      CL  2020-03-04 05:35:12
# 598      Saint-François              90      FR  2020-03-04 05:35:13
# 599             Ballina              75      AU  2020-03-04 05:35:13
# 600            Portland              90      US  2020-03-04 05:35:13
#
#          Humidity (%)  Latitude  Longitude  Max Temp (F)  Wind Speed (MPH)
# City_ID
# ...

# %%
html = indexed.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness (%)</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity (%)</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp (F)</th>
#       <th>Wind Speed (MPH)</th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ushuaia</td>
#       <td>40</td>
#       <td>AR</td>
#       <td>2020-03-04 05:28:50</td>
#       <td>58</td>
#       <td>-54.80</td>
#       <td>-68.30</td>
#       <td>53.60</td>
#       <td>25.28</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Tuktoyaktuk</td>
#       <td>20</td>
#       <td>CA</td>
#       <td>2020-03-04 05:33:01</td>
# ...
